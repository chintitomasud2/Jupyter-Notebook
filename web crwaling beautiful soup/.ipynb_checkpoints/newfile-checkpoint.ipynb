# %%
from CustomModule.Crawler import *

# %%
# Out:
# ['http://dspace.uiu.ac.bd/',
#  'http://webemail.uiu.ac.bd',
#  'http://library.uiu.ac.bd',
#  'http://iqac.uiu.ac.bd/',
#  'http://alumni.uiu.ac.bd',
#  'http://degver.uiu.ac.bd',
#  'http://www.uiu.ac.bd/jobs/',
#  'http://admission.uiu.ac.bd',
#  'https://www.uiu.ac.bd/',
#  'http://www.uiu.ac.bd',
#  'https://www.uiu.ac.bd/about-uiu/',
#  'https://www.uiu.ac.bd/about-uiu/vision-mission-goals/',
#  'https://www.uiu.ac.bd/about-uiu/general-information/',
#  'https://www.uiu.ac.bd/offices/',
#  'https://www.uiu.ac.bd/offices/office-of-the-registrar/',
#  'http://www.uiu.ac.bd/people/office-of-the-registrar/',
#  'http://www.uiu.ac.bd/offices/office-of-the-controller-of-examinations/',
#  'http://www.uiu.ac.bd/people/office-of-the-controller-of-examinations/',
#  'https://www.uiu.ac.bd/offices/dsa/',
#  'http://www.uiu.ac.bd/offices/dsa/clubs-under-dsa/',
#  'http://www.uiu.ac.bd/offices/dsa/',
#  'https://www.uiu.ac.bd/offices/career-counseling-center/',
# ...
